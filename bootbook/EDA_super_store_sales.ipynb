# %% [markdown]
# # 1. Asking Questions

# %% [markdown]
# 1. What day of the week are our sales high on average?
#
# 2. What is monthly average sales?
#
# 3. What are the year over growth year/ total sales over the years?
#
# 4. Who are the top customer of all times?
#
# 5. What are the highest sales by category?
#
# 6. Which city does have the highest sales?

# %% [markdown]
# # 2. Data Wrengling

# %% [markdown]
# 1.   Gatherring Data
# 2.   Assessing Data
# 3.   Cleaning Data

# %% [markdown]
# ## 1.   Gatherring Data
# * CSV files
# *  APIs
# *  Web Scraping
# *  Database

# %% [markdown]
# **Summary about Dataset**
#
#
# This dataset about a super store who sale their products online in america. This data set has only one file which contain 18 different columns and 9800 records. Main fetures  here Order date, Ship Date, Sales region, state, product cand product categories etc. This data set shows sale of region wise, product wise, date wise and can be extract lot of information. This dataset donwloaded from keggle.com website. Time frame of of sales here 2015 to 2018.
#
#
# **About Yield_df.csv**
# 1. Data set has only one file downloaded from keggle.com.
# 2. Columns of this Data set('Row ID', 'Order ID', 'Order Date', 'Ship Date', 'Ship Mode',
#        'Customer ID', 'Customer Name', 'Segment', 'Country', 'City', 'State',
#        'Postal Code', 'Region', 'Product ID', 'Category', 'Sub-Category',
#        'Product Name', 'Sales')

# %%
# important libraries
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import plotly.express as px

# %%
df = pd.read_csv('data\\train.csv')

# %% [markdown]
# ### Processing on **train** file

# %% [markdown]
# ----------------------**Summary About df_yield file**---------------------------
#
# * 'Row ID'---------> Row ID shows number of a record in data set.
# * 'Order ID'-------> Order ID shows orders unique number which is object data type.
# * 'Order Date'-----> THis shows the date of order when ordered a prodcut.
# * 'Ship Date'------> this is the date on which order shiped from source.
# * 'Ship Mode'------> It shows the mode of shiping Class (Same Day, First Class, Second Class, Standard)
# * 'Customer ID'----> It is the unique idenetification of a customer.
# * 'Customer Name'--> Shows the  name of customer.
# * 'Segment'--------> This columns shows the buyers categories(Consumer, Corporate ,Home, Office )
# * 'Country'--------> This column shows the country (United States).
# * 'City'-----------> This also shows the city name of super store.
# * 'State'----------> This shows the state of store.
# * 'Postal Code'----> Postal code
# * 'Region'---------> Region shows area of location(West,East,Central,South).
# * 'Product ID'-----> This shows the unique identification of product
# * 'Category'-------> This column shows the cate of product like(Office Supplies, Furniture, Technology)
# * 'Sub-Category'---> This column shows narrow category of product(total categories 18).
# * 'Product Name'---> Product name shows description of product.
# * 'Sales'----------> this shows the sale price of product.

# %% [markdown]
# Test

# %% [markdown]
# ## 2.   Assessing Data

# %% [markdown]
#   *   Types Unclean Data
#       *   Dirty Data
#       *   Messy Data
#   *   Types of Assessment
#       *   Manual Assessment
#       *   Programtic Assessment

# %% [markdown]
# *   **Dirty Data**
#   *   Completeness------------> (Missing Data) Missing values like (Nan)
#   *   Consistancy ------------> (Corrupt Data) Both data valid and accurate  but not accurate like (NY and New York bothwords meaning same but wrriten in different way)
#   *   Validity --------------> (Duplicated Data)
#   *   Accuracy---------------> (Incorrect Data) Data is but not accurate like (a man weight is = 1kg)

# %% [markdown]
# --------------------------------------------**Issue with data (Dirty type Data)**--------------------------------------------
# * Postal Code---has nan values **Accuracy**
# * Row Id---> i think it is useless in our case
# * Customer Id---> i think it is useless in our case
# * Order ID Id---> i think it is useless in our case
# * Product ID---> i think it is useless in our case
# * Country---> Whole data only one country so i think not so important remove it
# * Shipping_timeframe--> diffrence between order date and ship date is negative which unvlid data (**Validity**)
#
# --------------------------------------------**Issue with data (Messy type Data)**--------------------------------------------
#
# * Order Date--> Date formate should be changed
# * Ship Date---> Date formate should be changed
# * Postal code-> Should be data type Object.
# * Sales------->     Cahnage Sales column name to Price
# * Price------->     Change Price column data type to int.

# %% [markdown]
# *   **Messy Data**
#   *   Each variable forms column
#   *   Each observation forms a row
#   *   Each observational unit forms a table

# %%
# Manuall Assessment of Data
#df.head(50)
df.sample(5)
#df.tail(50)
# Out:
#       Row ID        Order ID  Order Date   Ship Date       Ship Mode  \
# 3773    3774  US-2015-102715  11/04/2015  13/04/2015    Second Class
# 2308    2309  US-2018-120418  11/06/2018  12/06/2018     First Class
# 5911    5912  CA-2017-155383  17/12/2017  22/12/2017  Standard Class
# 1351    1352  CA-2017-162901  28/03/2017  31/03/2017     First Class
# 4745    4746  CA-2018-168123  05/03/2018  05/03/2018        Same Day
#
#      Customer ID   Customer Name      Segment        Country       City  \
# 3773    JK-15370      Jay Kimmel     Consumer  United States      Miami
# 2308    BC-11125   Becky Castell  Home Office  United States     Peoria
# 5911    SC-20680   Steve Carroll  Home Office  United States    Seattle
# 1351    AS-10045  Aaron Smayling    Corporate  United States  Arlington
# 4745    JD-16060    Julia Dunbar     Consumer  United States  Rochester
#
#            State  Postal Code   Region       Product ID         Category  \
# ...

# %%
#progmatic Assessment
#df.head(10)

# %%
#df.tail(10)

# %%
#df.sample(10)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 9800 entries, 0 to 9799
# Data columns (total 18 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   Row ID         9800 non-null   int64
#  1   Order ID       9800 non-null   object
#  2   Order Date     9800 non-null   object
#  3   Ship Date      9800 non-null   object
#  4   Ship Mode      9800 non-null   object
#  5   Customer ID    9800 non-null   object
#  6   Customer Name  9800 non-null   object
#  7   Segment        9800 non-null   object
#  8   Country        9800 non-null   object
#  9   City           9800 non-null   object
#  10  State          9800 non-null   object
#  11  Postal Code    9789 non-null   float64
#  12  Region         9800 non-null   object
#  13  Product ID     9800 non-null   object
#  14  Category       9800 non-null   object
#  15  Sub-Category   9800 non-null   object
#  16  Product Name   9800 non-null   object
# ...

# %% [markdown]
# Asssesed Info:
# * Order Date and Ship Date (Object) type should be (datetime)
# * Sales data type is (float) should be in (int)
# * Postal Code is in (Float) should be in (Cat)

# %%
df.describe()
# Out:
#             Row ID   Postal Code         Sales
# count  9800.000000   9789.000000   9800.000000
# mean   4900.500000  55273.322403    230.769059
# std    2829.160653  32041.223413    626.651875
# min       1.000000   1040.000000      0.444000
# 25%    2450.750000  23223.000000     17.248000
# 50%    4900.500000  58103.000000     54.490000
# 75%    7350.250000  90008.000000    210.605000
# max    9800.000000  99301.000000  22638.480000

# %%
# duplicated
df.duplicated().sum()
# Out:
# 0

# %% [markdown]
# Assesment Info:
# * non any value is duplicated()

# %%
df.isnull().sum()
# Out:
# Row ID            0
# Order ID          0
# Order Date        0
# Ship Date         0
# Ship Mode         0
# Customer ID       0
# Customer Name     0
# Segment           0
# Country           0
# City              0
# State             0
# Postal Code      11
# Region            0
# Product ID        0
# Category          0
# Sub-Category      0
# Product Name      0
# Sales             0
# dtype: int64

# %% [markdown]
# Assessment info:
# * Here is 11 values nan of Product Code

# %%
df[df['Postal Code'].isnull()]
# Out:
#       Row ID        Order ID  Order Date   Ship Date       Ship Mode  \
# 2234    2235  CA-2018-104066  05/12/2018  10/12/2018  Standard Class
# 5274    5275  CA-2016-162887  07/11/2016  09/11/2016    Second Class
# 8798    8799  US-2017-150140  06/04/2017  10/04/2017  Standard Class
# 9146    9147  US-2017-165505  23/01/2017  27/01/2017  Standard Class
# 9147    9148  US-2017-165505  23/01/2017  27/01/2017  Standard Class
# 9148    9149  US-2017-165505  23/01/2017  27/01/2017  Standard Class
# 9386    9387  US-2018-127292  19/01/2018  23/01/2018  Standard Class
# 9387    9388  US-2018-127292  19/01/2018  23/01/2018  Standard Class
# 9388    9389  US-2018-127292  19/01/2018  23/01/2018  Standard Class
# 9389    9390  US-2018-127292  19/01/2018  23/01/2018  Standard Class
# 9741    9742  CA-2016-117086  08/11/2016  12/11/2016  Standard Class
#
#      Customer ID     Customer Name      Segment        Country        City  \
# ...

# %%
df[(df.City == 'Burlington') & (df.State == 'Vermont')]
# Out:
#       Row ID        Order ID  Order Date   Ship Date       Ship Mode  \
# 2234    2235  CA-2018-104066  05/12/2018  10/12/2018  Standard Class
# 5274    5275  CA-2016-162887  07/11/2016  09/11/2016    Second Class
# 8798    8799  US-2017-150140  06/04/2017  10/04/2017  Standard Class
# 9146    9147  US-2017-165505  23/01/2017  27/01/2017  Standard Class
# 9147    9148  US-2017-165505  23/01/2017  27/01/2017  Standard Class
# 9148    9149  US-2017-165505  23/01/2017  27/01/2017  Standard Class
# 9386    9387  US-2018-127292  19/01/2018  23/01/2018  Standard Class
# 9387    9388  US-2018-127292  19/01/2018  23/01/2018  Standard Class
# 9388    9389  US-2018-127292  19/01/2018  23/01/2018  Standard Class
# 9389    9390  US-2018-127292  19/01/2018  23/01/2018  Standard Class
# 9741    9742  CA-2016-117086  08/11/2016  12/11/2016  Standard Class
#
#      Customer ID     Customer Name      Segment        Country        City  \
# ...

# %% [markdown]
# Assesment Info:
# * I have assess here nan values in Postal code (city= Burlington, state of Vermont)
# * To check in google Bulington postal code fill in data set

# %% [markdown]
# To checking timeframe validity

# %% [markdown]
# ## 3.   Cleaning  Data & Feature Engineering
#
# **Order of Severity and Data Cleaning Oreder**
#
# Completeness--->Tidiness----> Validity----> Accracy----> Consistancy
#
#   *   Steps involved in Data Cleaning
#       *   Define
#       *   Code
#       *   Test

# %% [markdown]
# ### 3.1 Cleaning Data

# %% [markdown]
# Problem 1:  ----->  Postal Code has nan values**validity**
#
# Proposed solution: ------> Postal code nan values fill with (05402) because Burlington code is (05402)

# %%
# nan value fill
df['Postal Code'].fillna('05402',inplace=True)

# %% [markdown]
# Test

# %%
df.isnull().sum()
# Out:
# Row ID           0
# Order ID         0
# Order Date       0
# Ship Date        0
# Ship Mode        0
# Customer ID      0
# Customer Name    0
# Segment          0
# Country          0
# City             0
# State            0
# Postal Code      0
# Region           0
# Product ID       0
# Category         0
# Sub-Category     0
# Product Name     0
# Sales            0
# dtype: int64

# %% [markdown]
# Problem 2:-------> Row ID is unnecssry column need to remove it
#
# Proposed Solution: ------> Using drop function.

# %%
df.drop(['Row ID'], axis=1, inplace=True)
df.drop(['Order ID'], axis=1, inplace=True)
df.drop(['Product ID'], axis=1, inplace=True)
df.drop(['Customer ID'], axis=1, inplace=True)
df.drop([ 'Country'], axis=1, inplace=True )

# %% [markdown]
# Test:

# %%
df.head(2)
# Out:
#    Order Date   Ship Date     Ship Mode Customer Name   Segment       City  \
# 0  08/11/2017  11/11/2017  Second Class   Claire Gute  Consumer  Henderson
# 1  08/11/2017  11/11/2017  Second Class   Claire Gute  Consumer  Henderson
#
#       State Postal Code Region   Category Sub-Category  \
# 0  Kentucky     42420.0  South  Furniture    Bookcases
# 1  Kentucky     42420.0  South  Furniture       Chairs
#
#                                         Product Name   Sales
# 0                  Bush Somerset Collection Bookcase  261.96
# 1  Hon Deluxe Fabric Upholstered Stacking Chairs,...  731.94

# %% [markdown]
# Problem 3:-------> To change data type of Oder date and Ship Date.
#
# Proposed Solution: ------> using Pd.to_datetime() function.

# %%
df['Order Date'] = pd.to_datetime(df['Order Date'])
df['Ship Date'] = pd.to_datetime(df['Ship Date'])
# Out:
# C:\Users\M_ISHFAQ\AppData\Local\Temp\ipykernel_7488\312075123.py:1: UserWarning: Parsing dates in DD/MM/YYYY format when dayfirst=False (the default) was specified. This may lead to inconsistently parsed dates! Specify a format to ensure consistent parsing.
#   df['Order Date'] = pd.to_datetime(df['Order Date'])
# C:\Users\M_ISHFAQ\AppData\Local\Temp\ipykernel_7488\312075123.py:2: UserWarning: Parsing dates in DD/MM/YYYY format when dayfirst=False (the default) was specified. This may lead to inconsistently parsed dates! Specify a format to ensure consistent parsing.
#   df['Ship Date'] = pd.to_datetime(df['Ship Date'])

# %%
# to extract year month and day
df['Order Year'] = df['Order Date'].dt.year
df['Order Month'] = df['Order Date'].dt.month
df['Order Day'] = df['Order Date'].dt.day

# %% [markdown]
# Test:

# %%
df.head(2)
# Out:
#   Order Date  Ship Date     Ship Mode Customer Name   Segment       City  \
# 0 2017-08-11 2017-11-11  Second Class   Claire Gute  Consumer  Henderson
# 1 2017-08-11 2017-11-11  Second Class   Claire Gute  Consumer  Henderson
#
#       State Postal Code Region   Category Sub-Category  \
# 0  Kentucky     42420.0  South  Furniture    Bookcases
# 1  Kentucky     42420.0  South  Furniture       Chairs
#
#                                         Product Name   Sales  Order Year  \
# 0                  Bush Somerset Collection Bookcase  261.96        2017
# 1  Hon Deluxe Fabric Upholstered Stacking Chairs,...  731.94        2017
#
#    Order Month  Order Day
# 0            8         11
# 1            8         11

# %% [markdown]
# Problem 4:-------> Postal code data type change into (Cat).
#
# Proposed Solution: ------> using astype() function.

# %%
df['Postal Code'] = df['Postal Code'].astype('O')

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 9800 entries, 0 to 9799
# Data columns (total 16 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   Order Date     9800 non-null   datetime64[ns]
#  1   Ship Date      9800 non-null   datetime64[ns]
#  2   Ship Mode      9800 non-null   object
#  3   Customer Name  9800 non-null   object
#  4   Segment        9800 non-null   object
#  5   City           9800 non-null   object
#  6   State          9800 non-null   object
#  7   Postal Code    9800 non-null   object
#  8   Region         9800 non-null   object
#  9   Category       9800 non-null   object
#  10  Sub-Category   9800 non-null   object
#  11  Product Name   9800 non-null   object
#  12  Sales          9800 non-null   float64
#  13  Order Year     9800 non-null   int64
#  14  Order Month    9800 non-null   int64
#  15  Order Day      9800 non-null   int64
# dtypes: datetime64[ns](2), float64(1), int64(3), object(10)
# ...

# %% [markdown]
# Problem 5:-------> change Sales to price name.
#
# Proposed Solution: ------> using rename function.

# %%
# rename the column names
df.rename(columns={'Sales':'Price'}, inplace=True)

# %% [markdown]
# Test:

# %%
df.head(2)
# Out:
#   Order Date  Ship Date     Ship Mode Customer Name   Segment       City  \
# 0 2017-08-11 2017-11-11  Second Class   Claire Gute  Consumer  Henderson
# 1 2017-08-11 2017-11-11  Second Class   Claire Gute  Consumer  Henderson
#
#       State Postal Code Region   Category Sub-Category  \
# 0  Kentucky     42420.0  South  Furniture    Bookcases
# 1  Kentucky     42420.0  South  Furniture       Chairs
#
#                                         Product Name   Price  Order Year  \
# 0                  Bush Somerset Collection Bookcase  261.96        2017
# 1  Hon Deluxe Fabric Upholstered Stacking Chairs,...  731.94        2017
#
#    Order Month  Order Day
# 0            8         11
# 1            8         11

# %% [markdown]
# Problem 6:-------> Price Date type Should be in int.
#
# Proposed Solution: ------> using astype() function.

# %%
df['Price']=df['Price'].astype('int')

# %% [markdown]
# Test:

# %%
df['Price'].dtype
# Out:
# dtype('int32')

# %% [markdown]
# ### 3.2 Feature Engineering

# %% [markdown]
# Make New column (Shipping_Timeframe)

# %%
df['Shipping_timeframe']= df['Ship Date'] - df['Order Date']

# %%
df['Shipping_timeframe'].dtypes # Type of object is object.
# Out:
# dtype('<m8[ns]')

# %%
df['Shipping_timeframe']=df['Shipping_timeframe'].astype('str')
df['Shipping_timeframe']
# Out:
# 0         92 days
# 1         92 days
# 2       -173 days
# 3        -23 days
# 4        -23 days
#           ...
# 9795       7 days
# 9796    -319 days
# 9797    -319 days
# 9798    -319 days
# 9799    -319 days
# Name: Shipping_timeframe, Length: 9800, dtype: object

# %%
df['Shipping_timeframe'] = df['Shipping_timeframe'].str.split().str[0]

# %%
df.head(4)
# Out:
#   Order Date  Ship Date       Ship Mode    Customer Name    Segment  \
# 0 2017-08-11 2017-11-11    Second Class      Claire Gute   Consumer
# 1 2017-08-11 2017-11-11    Second Class      Claire Gute   Consumer
# 2 2017-12-06 2017-06-16    Second Class  Darrin Van Huff  Corporate
# 3 2016-11-10 2016-10-18  Standard Class   Sean O'Donnell   Consumer
#
#               City       State Postal Code Region         Category  \
# 0        Henderson    Kentucky     42420.0  South        Furniture
# 1        Henderson    Kentucky     42420.0  South        Furniture
# 2      Los Angeles  California     90036.0   West  Office Supplies
# 3  Fort Lauderdale     Florida     33311.0  South        Furniture
#
#   Sub-Category                                       Product Name  Price  \
# 0    Bookcases                  Bush Somerset Collection Bookcase    261
# 1       Chairs  Hon Deluxe Fabric Upholstered Stacking Chairs,...    731
# ...

# %%
df['Shipping_timeframe']=df['Shipping_timeframe'].astype('int')

# %%
df[df['Shipping_timeframe'] < 0]
#I said that it is not logical to have negative values in this column but I have what should I do?
# Out:
#      Order Date  Ship Date       Ship Mode     Customer Name    Segment  \
# 2    2017-12-06 2017-06-16    Second Class   Darrin Van Huff  Corporate
# 3    2016-11-10 2016-10-18  Standard Class    Sean O'Donnell   Consumer
# 4    2016-11-10 2016-10-18  Standard Class    Sean O'Donnell   Consumer
# 5    2015-09-06 2015-06-14  Standard Class   Brosina Hoffman   Consumer
# 6    2015-09-06 2015-06-14  Standard Class   Brosina Hoffman   Consumer
# ...         ...        ...             ...               ...        ...
# 9790 2018-03-27 2018-01-04  Standard Class   Caroline Jumper   Consumer
# 9796 2016-12-01 2016-01-17  Standard Class  Cindy Schnelling  Corporate
# 9797 2016-12-01 2016-01-17  Standard Class  Cindy Schnelling  Corporate
# 9798 2016-12-01 2016-01-17  Standard Class  Cindy Schnelling  Corporate
# 9799 2016-12-01 2016-01-17  Standard Class  Cindy Schnelling  Corporate
#
#                  City       State Postal Code   Region         Category  \
# ...

# %% [markdown]
# Assesment Info:
# * Here is 1684  record how shipping timeframe is negative ilogical should be remove

# %%
cleaned_df =df[df['Shipping_timeframe'] >= 0]

# %%
cleaned_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 8116 entries, 0 to 9795
# Data columns (total 17 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   Order Date          8116 non-null   datetime64[ns]
#  1   Ship Date           8116 non-null   datetime64[ns]
#  2   Ship Mode           8116 non-null   object
#  3   Customer Name       8116 non-null   object
#  4   Segment             8116 non-null   object
#  5   City                8116 non-null   object
#  6   State               8116 non-null   object
#  7   Postal Code         8116 non-null   object
#  8   Region              8116 non-null   object
#  9   Category            8116 non-null   object
#  10  Sub-Category        8116 non-null   object
#  11  Product Name        8116 non-null   object
#  12  Price               8116 non-null   int32
#  13  Order Year          8116 non-null   int64
#  14  Order Month         8116 non-null   int64
# ...

# %% [markdown]
# #### Cleaned Dataset and Brief Summary
#
# New cleaned data have total  14 columns. 10 columns are **object type** , 2 columns are **datetime** and 2 columns are **int type**.

# %%
cleaned_df.head(10)
# Out:
#    Order Date  Ship Date       Ship Mode    Customer Name      Segment  \
# 0  2017-08-11 2017-11-11    Second Class      Claire Gute     Consumer
# 1  2017-08-11 2017-11-11    Second Class      Claire Gute     Consumer
# 12 2018-04-15 2018-04-20  Standard Class     Andrew Allen     Consumer
# 13 2017-05-12 2017-10-12  Standard Class     Irene Maddox     Consumer
# 14 2016-11-22 2016-11-26  Standard Class    Harold Pawlan  Home Office
# 15 2016-11-22 2016-11-26  Standard Class    Harold Pawlan  Home Office
# 16 2015-11-11 2015-11-18  Standard Class        Pete Kriz     Consumer
# 17 2015-05-13 2015-05-15    Second Class  Alejandro Grove     Consumer
# 21 2017-09-12 2017-12-13  Standard Class        Ken Black    Corporate
# 22 2017-09-12 2017-12-13  Standard Class        Ken Black    Corporate
#
#            City           State Postal Code   Region         Category  \
# 0     Henderson        Kentucky     42420.0    South        Furniture
# ...

# %%
cleaned_df.nunique()
# Out:
# Order Date            1072
# Ship Date             1173
# Ship Mode                4
# Customer Name          791
# Segment                  3
# City                   506
# State                   49
# Postal Code            602
# Region                   4
# Category                 3
# Sub-Category            17
# Product Name          1827
# Price                 1052
# Order Year               4
# Order Month             12
# Order Day               31
# Shipping_timeframe      54
# dtype: int64

# %%
cleaned_df.describe().T
# Out:
#                      count         mean         std     min     25%     50%  \
# Price               8116.0   234.348448  663.065941     0.0    17.0    54.0
# Order Year          8116.0  2016.732011    1.124539  2015.0  2016.0  2017.0
# Order Month         8116.0     6.814194    3.445658     1.0     4.0     7.0
# Order Day           8116.0    15.727945    7.181781     1.0    11.0    15.0
# Shipping_timeframe  8116.0    41.726836   58.037943     0.0     4.0     5.0
#
#                        75%      max
# Price                211.0  22638.0
# Order Year          2018.0   2018.0
# Order Month           10.0     12.0
# Order Day             21.0     31.0
# Shipping_timeframe    89.0    214.0

# %%
cat_columns = []
for cat in cleaned_df.columns:
    if cleaned_df[cat].dtypes=='object':
        cat_columns.append(cat)
#I created category_columns list to observe the category columns features.

# %%
cleaned_df[cat_columns].describe()
# Out:
#              Ship Mode Customer Name   Segment           City       State  \
# count             8116          8116      8116           8116        8116
# unique               4           791         3            506          49
# top     Standard Class  Matt Abelman  Consumer  New York City  California
# freq              4639            34      4236            762        1640
#
#         Postal Code Region         Category Sub-Category     Product Name
# count        8116.0   8116             8116         8116             8116
# unique        602.0      4                3           17             1827
# top         10035.0   West  Office Supplies      Binders  Staple envelope
# freq          205.0   2603             4895         1265               39

# %%
cleaned_df[['Order Date', 'Ship Date']].describe().T
# Here I want to choose two columns from dataframe so I have to use two bracket.
# Out:
# C:\Users\M_ISHFAQ\AppData\Local\Temp\ipykernel_7488\2680266515.py:1: FutureWarning: Treating datetime data as categorical rather than numeric in `.describe` is deprecated and will be removed in a future version of pandas. Specify `datetime_is_numeric=True` to silence this warning and adopt the future behavior now.
#   cleaned_df[['Order Date', 'Ship Date']].describe().T
# C:\Users\M_ISHFAQ\AppData\Local\Temp\ipykernel_7488\2680266515.py:1: FutureWarning: Treating datetime data as categorical rather than numeric in `.describe` is deprecated and will be removed in a future version of pandas. Specify `datetime_is_numeric=True` to silence this warning and adopt the future behavior now.
#   cleaned_df[['Order Date', 'Ship Date']].describe().T
#            count unique        top freq      first       last
# Order Date  8116   1072 2017-05-09   38 2015-01-02 2018-12-30
# Ship Date   8116   1173 2018-09-26   34 2015-01-15 2019-05-01

# %% [markdown]
# Order Date: sterted from 2015-01-02 to 2018-12-30
# Ship Date: strated from 2015-01-04 to 2019-05-01
#
# Top Oderd Date: 2017-05-09 frequency 38
# Top ship Date: 2018-09-26 frequency 34

# %%
for column in cat_columns:
    print(column)
    print(cleaned_df[column].value_counts())
    print('END')
    print("")

     #This method gives us to total information about each column's count
# Out:
# Ship Mode
# Standard Class    4639
# Second Class      1597
# First Class       1344
# Same Day           536
# Name: Ship Mode, dtype: int64
# END
#
# Customer Name
# Matt Abelman         34
# John Lee             30
# Seth Vernon          30
# Lena Cacioppo        30
# Paul Prost           30
#                      ..
# Cathy Hwang           1
# Anthony O'Donnell     1
# Greg Matthias         1
# Alyssa Crouse         1
# Ritsa Hightower       1
# Name: Customer Name, Length: 791, dtype: int64
# END
#
# Segment
# Consumer       4236
# Corporate      2441
# Home Office    1439
# Name: Segment, dtype: int64
# END
#
# City
# New York City    762
# Los Angeles      599
# Philadelphia     435
# San Francisco    415
# Seattle          333
#                 ...
# Bartlett           1
# San Mateo          1
# Yucaipa            1
# Mission Viejo      1
# Springdale         1
# Name: City, Length: 506, dtype: int64
# END
#
# State
# California              1640
# ...

# %% [markdown]
# ## Feature Engineering & Data Cleaning

# %%
cleaned_df.groupby('Ship Mode').agg({'Shipping_timeframe':'mean'})
# Out:
#                 Shipping_timeframe
# Ship Mode
# First Class              26.311756
# Same Day                  0.891791
# Second Class             36.224796
# Standard Class           52.805130

# %% [markdown]
# Results: Standard class most frequently used with percentage (52.805130)

# %%
cleaned_df.groupby('Ship Mode').agg({'Shipping_timeframe':'median'})
# Out:
#                 Shipping_timeframe
# Ship Mode
# First Class                    3.0
# Same Day                       0.0
# Second Class                   4.0
# Standard Class                 6.0

# %%
ship_mode_dic = {"Standard Class":6,
                 "Second Class":4, 
                 "Same Day":0, 
                 "First Class":3}
ship_mode_dic.items()
# Out:
# dict_items([('Standard Class', 6), ('Second Class', 4), ('Same Day', 0), ('First Class', 3)])

# %%
for key, value in ship_mode_dic.items():
  cleaned_df['Ship Date'] = np.where((cleaned_df['Shipping_timeframe'] < 0) & (cleaned_df['Ship Mode'] == key),
                             cleaned_df['Order Date'] + (cleaned_df['Order Date']-cleaned_df['Ship Date']),
                             cleaned_df['Ship Date'])
# Out:
# C:\Users\M_ISHFAQ\AppData\Local\Temp\ipykernel_7488\1117805937.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   cleaned_df['Ship Date'] = np.where((cleaned_df['Shipping_timeframe'] < 0) & (cleaned_df['Ship Mode'] == key),

# %%
cleaned_df.head()
# Out:
#    Order Date  Ship Date       Ship Mode  Customer Name      Segment  \
# 0  2017-08-11 2017-11-11    Second Class    Claire Gute     Consumer
# 1  2017-08-11 2017-11-11    Second Class    Claire Gute     Consumer
# 12 2018-04-15 2018-04-20  Standard Class   Andrew Allen     Consumer
# 13 2017-05-12 2017-10-12  Standard Class   Irene Maddox     Consumer
# 14 2016-11-22 2016-11-26  Standard Class  Harold Pawlan  Home Office
#
#           City           State Postal Code   Region         Category  \
# 0    Henderson        Kentucky     42420.0    South        Furniture
# 1    Henderson        Kentucky     42420.0    South        Furniture
# 12     Concord  North Carolina     28027.0    South  Office Supplies
# 13     Seattle      Washington     98103.0     West  Office Supplies
# 14  Fort Worth           Texas     76106.0  Central  Office Supplies
#
#    Sub-Category                                       Product Name  Price  \
# ...

# %% [markdown]
# # 3. Exploratory Data Analysis

# %% [markdown]
# ### Why do EDA
#
# - Model building
# - Analysis and reporting
# - Validate assumptions
# - Handling missing values
# - feature engineering
# - detecting outliers
# ### Univariate Analysis
#
# Univariate analysis focuses on analyzing each feature in the dataset independently.
#
# - **Distribution analysis**: The distribution of each feature is examined to identify its shape, central tendency, and dispersion.
#
# - **Identifying potential issues**: Univariate analysis helps in identifying potential problems with the data such as outliers, skewness, and missing values
# #### The shape of a data distribution refers to its overall pattern or form as it is represented on a graph. Some common shapes of data distributions include:
#
# - **Normal Distribution**: A symmetrical and bell-shaped distribution where the mean, median, and mode are equal and the majority of the data falls in the middle of the distribution with gradually decreasing frequencies towards the tails.
#
# - **Skewed Distribution**: A distribution that is not symmetrical, with one tail being longer than the other. It can be either positively skewed (right-skewed) or negatively skewed (left-skewed).
#
# - **Bimodal Distribution**: A distribution with two peaks or modes.
#
# - **Uniform Distribution**: A distribution where all values have an equal chance of occurring.
#
# The shape of the data distribution is important in identifying the presence of outliers, skewness, and the type of statistical tests and models that can be used for further analysis.
#
# #### **Dispersion** is a statistical term used to describe the spread or variability of a set of data. It measures how far the values in a data set are spread out from the central tendency (mean, median, or mode) of the data.
#
# There are several measures of dispersion, including:
#
# - **Range**: The difference between the largest and smallest values in a data set.
#
# - **Variance**: The average of the squared deviations of each value from the mean of the data set.
#
# - **Standard Deviation**: The square root of the variance. It provides a measure of the spread of the data that is in the same units as the original data.
#
# - **Interquartile range (IQR)**: The range between the first quartile (25th percentile) and the third quartile (75th percentile) of the data.
#
# Dispersion helps to describe the spread of the data, which can help to identify the presence of outliers and skewness in the data.
#
# ### Steps of doing Univariate Analysis on Numerical columns
#
# - **Descriptive Statistics**: Compute basic summary statistics for the column, such as mean, median, mode, standard deviation, range, and quartiles. These statistics give a general understanding of the distribution of the data and can help identify skewness or outliers.
#
# - **Visualizations**: Create visualizations to explore the distribution of the data. Some common visualizations for numerical data include histograms, box plots, and density plots. These visualizations provide a visual representation of the distribution of the data and can help identify skewness an outliers.
#
# - **Identifying Outliers**: Identify and examine any outliers in the data. Outliers can be identified using visualizations. It is important to determine whether the outliers are due to measurement errors, data entry errors, or legitimate differences in the data, and to decide whether to include or exclude them from the analysis.
#
# - **Skewness**: Check for skewness in the data and consider transforming the data or using robust statistical methods that are less sensitive to skewness, if necessary.
#
# - **Conclusion**: Summarize the findings of the EDA and make decisions about how to proceed with further analysis.

# %%
cleaned_df['Price'].describe()
# Out:
# count     8116.000000
# mean       234.348448
# std        663.065941
# min          0.000000
# 25%         17.000000
# 50%         54.000000
# 75%        211.000000
# max      22638.000000
# Name: Price, dtype: float64

# %%
mode = cleaned_df['Price'].mode()

# %%
median = cleaned_df['Price'].median()

# %%
cleaned_df['Price'].skew()
# Out:
# 13.015072795563594

# %%
mean = np.mean(cleaned_df['Price'])
std= np.std(cleaned_df['Price'])
f,ax=plt.subplots(2,1,figsize=(20,16))
sns.histplot(cleaned_df['Price'], kde=True,ax=ax[0])
ax[0].axvline(mean, color='red', label='mean')
ax[0].axvline(mean + std, color='green', label='+1 std')
ax[0].axvline(mean - std, color='green', label='-1 std')
ax[0].set_title('Price')
ax[0].set_ylabel('')
cleaned_df['Price'].plot(kind='box',ax=ax[1])
ax[1].set_title('Price')
ax[0].legend()
plt.xticks(rotation = 45)
plt.show()

# %%
cleaned_df.columns
# Out:
# Index(['Order Date', 'Ship Date', 'Ship Mode', 'Customer Name', 'Segment',
#        'City', 'State', 'Postal Code', 'Region', 'Category', 'Sub-Category',
#        'Product Name', 'Price', 'Order Year', 'Order Month', 'Order Day',
#        'Shipping_timeframe'],
#       dtype='object')

# %%
mode = cleaned_df['Shipping_timeframe'].mode()

# %%
median = cleaned_df['Shipping_timeframe'].median()

# %%
cleaned_df['Shipping_timeframe'].skew()
# Out:
# 1.2297663789433426

# %%
mean = np.mean(cleaned_df['Shipping_timeframe'])
std= np.std(cleaned_df['Shipping_timeframe'])
f,ax=plt.subplots(2,1,figsize=(20,16))
sns.histplot(cleaned_df['Shipping_timeframe'], kde=True,ax=ax[0])
ax[0].axvline(mean, color='red', label='mean')
ax[0].axvline(mean + std, color='green', label='+1 std')
ax[0].axvline(mean - std, color='green', label='-1 std')
ax[0].set_title('Shipping_timeframe')
ax[0].set_ylabel('')
cleaned_df['Shipping_timeframe'].plot(kind='box',ax=ax[1])
ax[1].set_title('Shipping_timeframe')
ax[0].legend()
plt.xticks(rotation = 45)
plt.show()

# %%
f,ax=plt.subplots(1,2,figsize=(20,8))
cleaned_df['Ship Mode'].value_counts().plot.pie(shadow=True,autopct = '%1.1f%%', ax=ax[0])
ax[0].set_title('Ship Mode')
ax[0].set_ylabel('')
sns.countplot(data=df,x='Ship Mode', order=cleaned_df['Ship Mode'].value_counts().index)
ax[1].set_title('Ship Mode')
plt.xticks(rotation = 45)
plt.show()

# %% [markdown]
# ## **Ship Mode**
#
# **conclusions**
#
# - Here Total 4 modes of shipping
# - Standard Class    =    57.2%,
# - Second Class    =    19.7.14%,
# - First Class    =    16.6,
# - Same Day  =   6.6%,

# %%
f,ax=plt.subplots(1,2,figsize=(20,8))
cleaned_df['Segment'].value_counts().plot.pie(shadow=True,autopct = '%1.1f%%', ax=ax[0])
ax[0].set_title('Segment')
ax[0].set_ylabel('')
sns.countplot(data=df,x='Segment', order=cleaned_df['Segment'].value_counts().index)
ax[1].set_title('Segment')
plt.xticks(rotation = 45)
plt.show()

# %% [markdown]
# ## **Product Use Segments**
#
# **conclusions**
#
# - Here Total 3 Segments
# - Consumer    =    52.2%,
# - Corporate    =    30.1%,
# - Home Office    =    17.7%

# %%
cleaned_df.columns
# Out:
# Index(['Order Date', 'Ship Date', 'Ship Mode', 'Customer Name', 'Segment',
#        'City', 'State', 'Postal Code', 'Region', 'Category', 'Sub-Category',
#        'Product Name', 'Price', 'Order Year', 'Order Month', 'Order Day',
#        'Shipping_timeframe'],
#       dtype='object')

# %% [markdown]
# ## Sub- Categories

# %%
f,ax=plt.subplots(1,2,figsize=(20,8))
cleaned_df['Sub-Category'].value_counts().plot.pie(shadow=True,autopct = '%1.1f%%', ax=ax[0])
ax[0].set_title('Sub-Category')
ax[0].set_ylabel('')
sns.countplot(data=df,x='Sub-Category', order=cleaned_df['Sub-Category'].value_counts().index)
ax[1].set_title('Sub-Category')
plt.xticks(rotation = 45)
plt.show()

# %%
f,ax=plt.subplots(1,2,figsize=(20,8))
cleaned_df['Region'].value_counts().plot.pie(shadow=True,autopct = '%1.1f%%', ax=ax[0])
ax[0].set_title('Region')
ax[0].set_ylabel('')
sns.countplot(data=df,x='Region', order=cleaned_df['Region'].value_counts().index)
ax[1].set_title('Region')
plt.xticks(rotation = 45)
plt.show()

# %% [markdown]
# ## **Product Use Segments**
#
# **conclusions**
#
# - Here Total 4 Regions
# - West    =    32.1%,
# - East    =    28.2.1%,
# - Central =    23.3.7%
# - South   =    16.4%

# %%
# countplot
plt.figure(figsize=(20,10))
sns.countplot(data=cleaned_df,x='State', order=cleaned_df['State'].value_counts().index)
plt.xticks(rotation = 45)
plt.title('State')   
plt.show()

# %% [markdown]
# ## **State**
#
# **conclusions**
#
# - Here Total 49 state
# - These are top five states:
#     - California
#     - New York
#     - Texas
#     - Pennsylvania
#     - Illinois

# %%
f,ax=plt.subplots(1,2,figsize=(20,8))
cleaned_df['Category'].value_counts().plot.pie(shadow=True,autopct = '%1.1f%%', ax=ax[0])
ax[0].set_title('Category')
ax[0].set_ylabel('')
sns.countplot(data=df,x='Category', order=cleaned_df['Category'].value_counts().index)
ax[1].set_title('Region')
plt.xticks(rotation = 45)
plt.show()

# %% [markdown]
# ## **Category**
#
# **conclusions**
#
# - Here Total 3 Catefories
#
#     - Office Supplies
#     - Furniture
#     - Technology

# %%
f,ax=plt.subplots(1,2,figsize=(20,8))
cleaned_df['Sub-Category'].value_counts().plot.pie(shadow=True,autopct = '%1.1f%%', ax=ax[0])
ax[0].set_title('Sub-Category')
ax[0].set_ylabel('')
sns.countplot(data=df,x='Sub-Category', order=cleaned_df['Sub-Category'].value_counts().index)
ax[1].set_title('Sub-Category')
plt.xticks(rotation = 45)
plt.show()

# %% [markdown]
# ## **Sub- Categories**
#
# **conclusions**
#
# - Here Total 17 Sub-categories :
#     - Binders        15.586496
#     - Paper          13.553475
#     - Furnishings     9.450468
#     - Phones          8.785116
#     - Storage         8.464761
#     - Art             8.082799
#     - Accessories     7.713159
#     - Chairs          6.296205
#     - Appliances      4.669788
#     - Labels          3.511582
#     - Tables          3.240513
#     - Envelopes       2.402661
#     - Bookcases       2.291769
#     - Fasteners       2.082307
#     - Supplies        1.959093
#     - Machines        1.244455
#     - Copiers         0.665352

# %%
cleaned_df=cleaned_df.reset_index()

# %% [markdown]
# ## Monthly sales over the years

# %%
cleaned_df['weekday'] = cleaned_df['Order Date'].dt.day_name()
#I look at the "Order date" column using pandas dt method to find out which day the sale was made.

# %%
plt.figure(figsize=(15,5))
colorscales = px.colors.named_colorscales()
data_weekday = cleaned_df.groupby(['weekday']).agg({'Price': 'mean'}).reset_index()
data_weekday.sort_values(by='Price', inplace=True)
sns.barplot(x='weekday', y='Price', data=data_weekday).set(title="Average sales by day of the week");

# %% [markdown]
# **BI-Variant Analysis**
# ### Steps of doing Bivariate Analysis
#
# - Select 2 cols
# - Understand type of relationship
#     1. **Numerical - Numerical**<br>
#         a. You can plot graphs like scatterplot(regression plots), 2D histplot, 2D KDEplots<br>
#         b. Check correlation coefficent to check linear relationship
#     2. **Numerical - Categorical** - create visualizations that compare the distribution of the numerical data across different categories of the categorical data.<br>
#         a. You can plot graphs like barplot, boxplot, kdeplot violinplot even scatterplots<br>
#     3. **Categorical - Categorical**<br>
#         a. You can create cross-tabulations or contingency tables that show the distribution of values in one categorical column, grouped by the values in the other categorical column.<br>
#         b. You can plots like heatmap, stacked barplots, treemaps
#
# - Write your conclusions

# %% [markdown]
# **Sale Over Years**
#
# *   Your Findings
#
#   1.  Sale not increase with passage of years.
#   2.  Sale highest the 2015.
#   3.  Sale down Both Even Years (2016,2018)

# %%
f,ax=plt.subplots(1,2,figsize=(26,8))
sns.barplot(data=cleaned_df,x='Order Year',y='Price', ax=ax[0])
ax[0].set_title('Years VS Sale')
ax[0].set_ylabel('Sale')
sns.boxplot(data=df,x='Order Year',y='Price', ax=ax[1])
ax[1].set_title('Years VS Sale')
ax[1].set_ylabel('Sale')

plt.xticks(rotation = 45)
plt.show()

# %% [markdown]
# **Sale Over Months**
#
# *   Your Findings
#
#   1.  Topest sale on First three Months and 8th.
#   2.  Lowest sale on th April to July.
#   3.  Last Four month average sale.

# %%
f,ax=plt.subplots(1,2,figsize=(26,8))
sns.barplot(data=cleaned_df,x='Order Month',y='Price', ax=ax[0])
ax[0].set_title('Moth VS Sale')
ax[0].set_ylabel('Sale')
sns.boxplot(data=df,x='Order Month',y='Price', ax=ax[1])
ax[1].set_title('Month VS Sale')
ax[1].set_ylabel('Sale')

plt.xticks(rotation = 45)
plt.show()

# %% [markdown]
# **Sale Over Month Days**
#
# *   Your Findings
#
#   1.  Top sale in the Month in start and mid of month.
#   2.  Lowest sale 3 to 9 dates.

# %%
f,ax=plt.subplots(1,2,figsize=(26,8))
sns.barplot(data=cleaned_df,x='Order Day',y='Price', ax=ax[0])
ax[0].set_title('Days of Month VS Sale')
ax[0].set_ylabel('Sale')
sns.boxplot(data=df,x='Order Day',y='Price', ax=ax[1])
ax[1].set_title('Days of Month VS Sale')
ax[1].set_ylabel('Sale')

plt.xticks(rotation = 45)
plt.show()

# %% [markdown]
# **Sale vs Ship Modes**
#
# *   Your Findings
#
#   1.  Every Mode of Shipment has equal sale.

# %%
f,ax=plt.subplots(1,2,figsize=(26,8))
sns.barplot(data=cleaned_df,x='Ship Mode',y='Price', ax=ax[0])
ax[0].set_title('Ship Mode VS Sale')
ax[0].set_ylabel('Sale')
sns.boxplot(data=df,x='Ship Mode',y='Price', ax=ax[1])
ax[1].set_title('Ship Mode VS Sale')
ax[1].set_ylabel('Sale')

plt.xticks(rotation = 45)
plt.show()

# %% [markdown]
# **Sale Over Product-Usage Segment**
#
# *   Your Findings
#
#   1.  Top sale Prodcuts are Home segemnt.
#   2.  Consumer segment is loest level and Corporate in midle.

# %%
f,ax=plt.subplots(1,2,figsize=(26,8))
sns.barplot(data=cleaned_df,x='Segment',y='Price', ax=ax[0])
ax[0].set_title('Segment VS Sale')
ax[0].set_ylabel('Sale')
sns.boxplot(data=df,x='Segment',y='Price', ax=ax[1])
ax[1].set_title('Segment VS Sale')
ax[1].set_ylabel('Sale')

plt.xticks(rotation = 45)
plt.show()

# %% [markdown]
# **Sale VS Sate**
#
# *   Your Findings
#
#   1.  Yield Sale Increase with passage of time.
#   2.  Peoduction of year 2003 is missing.
#   3.  Year 2013 has maximum Sale and 1990 is lowest Sale
#   4.  Average Sale differnce in 23 years 23639.547418999995 in hg/ha_yield.

# %%
f,ax=plt.subplots(2,1,figsize=(26,12))
sns.barplot(data=cleaned_df,x='State',y='Price', ax=ax[0])
ax[0].set_title('State VS Sale')
ax[0].set_ylabel('Sale')
sns.boxplot(data=df,x='State',y='Price', ax=ax[1])
ax[1].set_title('State VS Sale')
ax[1].set_ylabel('Sale')

plt.xticks(rotation = 45)
plt.show()

# %% [markdown]
# **Sale VS Graphical Regions**
#
# *   Your Findings
#
#   1.  South and East Region More sale compare than Central and West.

# %%
f,ax=plt.subplots(1,2,figsize=(26,8))
sns.barplot(data=cleaned_df,x='Region',y='Price', ax=ax[0])
ax[0].set_title('Region VS Sale')
ax[0].set_ylabel('Sale')
sns.boxplot(data=df,x='Region',y='Price', ax=ax[1])
ax[1].set_title('Region VS Sale')
ax[1].set_ylabel('Sale')

plt.xticks(rotation = 45)
plt.show()

# %% [markdown]
# **Sale VS Categories**
#
# *   Your Findings
#
#   1.  Techonlogy cat products high sale and demanding products.
#   2.  Office Supply cat Product low sale and Furniture sale is more than average.

# %%
'Category'
f,ax=plt.subplots(1,2,figsize=(26,8))
sns.barplot(data=cleaned_df,x='Category',y='Price', ax=ax[0])
ax[0].set_title('Category VS Sale')
ax[0].set_ylabel('Sale')
sns.boxplot(data=df,x='Category',y='Price', ax=ax[1])
ax[1].set_title('Category VS Sale')
ax[1].set_ylabel('Sale')

plt.xticks(rotation = 45)
plt.show()

# %% [markdown]
# **Sale VS Sub-Categories**
#
# *   Your Findings
#
#   1.  Coppier, Maches and Phones are sale copare than others.
# .

# %%
f,ax=plt.subplots(1,2,figsize=(26,8))
sns.barplot(data=cleaned_df,x='Sub-Category',y='Price', ax=ax[0])
ax[0].set_title('Sub-Category VS Sale')
ax[0].set_ylabel('Sale')
sns.boxplot(data=df,x='Sub-Category',y='Price', ax=ax[1])
ax[1].set_title('Sub-Category VS Sale')
ax[1].set_ylabel('Sale')

plt.xticks(rotation = 45)
plt.show()

# %% [markdown]
# **Sale VS Shiping_Timeframe**
#
# *   Your Findings
#
#   1.  Most of the Prodcuts deliver same day.
#   2.  Same Delivery products mostly low to high price products.
#   3.  After 200 days delivery products are low price prodcuts.

# %%
plt.subplots(figsize=(30,8))
sns.scatterplot(x=cleaned_df['Shipping_timeframe'],y=df['Price'], hue=df['Category'])
plt.title('Sale VS Shipping_timeframe')
plt.ylabel('Sale')

plt.xticks(rotation = 45)
plt.show()

# %%
# Over time changes in(Prodduction, average rainfall, temp, pesticides)
f,ax=plt.subplots(2,1,figsize=(26,8))
sns.lineplot(data=cleaned_df,x='Order Year',y='Price', ax=ax[0])
#ax[0].set_title('country VS hg/ha_yield')
#ax[0].set_ylabel('hg/ha_yield')
sns.lineplot(data=cleaned_df,x='Order Year',y='Shipping_timeframe', ax=ax[1])
#sns.lineplot(data=Cleaned_df,x='Order Year',y='avg_temp', ax=ax[2])
#sns.lineplot(data=Cleaned_df,x='Order Year',y='pesticides_in_tones', ax=ax[3])
plt.xticks(rotation = 90)
plt.show()

# %% [markdown]
# Crop Vs Sale

# %% [markdown]
# # 4. Data Drawing Conclusion

# %%
cleaned_df.groupby(['Order Date', 'Ship Mode']).agg({'Price':'sum'})
#I just want to see the "Ship Mode" and "Order Date" together.
# Out:
#                            Price
# Order Date Ship Mode
# 2015-01-02 First Class       468
# 2015-01-03 Second Class      457
#            Standard Class   1741
# 2015-01-04 Second Class       46
#            Standard Class     72
# ...                          ...
# 2018-12-28 Standard Class    580
# 2018-12-29 First Class         6
#            Second Class     1811
#            Standard Class   1092
# 2018-12-30 Standard Class    710
#
# [2087 rows x 1 columns]

# %%
data_daily_sales = df.groupby('Order Date').agg({'Price':"sum"}).reset_index()
#I grouped  my dataset by "Order Date" and I want that according to "Sales" sum.
data_daily_sales
# Out:
#      Order Date  Price
# 0    2015-01-02    468
# 1    2015-01-03   2198
# 2    2015-01-04    118
# 3    2015-01-06   5182
# 4    2015-01-07    599
# ...         ...    ...
# 1225 2018-12-26    813
# 1226 2018-12-27    177
# 1227 2018-12-28   1646
# 1228 2018-12-29   2909
# 1229 2018-12-30    710
#
# [1230 rows x 2 columns]

# %%
# fig = px.line(data_daily_sales, x='Order Date', y='Sales', title='Daily Sales')
plt.figure(figsize=(20,8))
sns.lineplot(x='Order Date', y='Price',data=data_daily_sales).set(title="Daily Sales")
plt.xticks(rotation=45)
plt.show()
#Generally, using line graph is more logical for daily information.
# I can say that seasonality(christmas- black friday extc) is not included in this data as it is a store that are selling office supplies.

# %% [markdown]
# ## Monthly sales over the years

# %%
cleaned_df['month_year'] = str(cleaned_df['Order Month']) + '-' + str(cleaned_df['Order Year'])

# %%
for i in range(len(cleaned_df)):
  cleaned_df['month_year'][i] = str(cleaned_df['Order Month'][i]) + "-" +str(cleaned_df['Order Year'][i])
# Out:
# C:\Users\M_ISHFAQ\AppData\Local\Temp\ipykernel_7488\1235190997.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   cleaned_df['month_year'][i] = str(cleaned_df['Order Month'][i]) + "-" +str(cleaned_df['Order Year'][i])

# %%
#If I want to combine two data, it is usually added as a string data type, and I add it this way.
cleaned_df['month_year'] = pd.to_datetime(cleaned_df['month_year'])

# %%
plt.figure(figsize=(15,5))
plt.title('Month and yearly sales')
sns.scatterplot(data=cleaned_df,x='month_year', y='Price')
plt.xticks(rotation=45)
# Out:
# (array([16436., 16617., 16801., 16983., 17167., 17348., 17532., 17713.,
#         17897.]),
#  [Text(16436.0, 0, '2015-01'),
#   Text(16617.0, 0, '2015-07'),
#   Text(16801.0, 0, '2016-01'),
#   Text(16983.0, 0, '2016-07'),
#   Text(17167.0, 0, '2017-01'),
#   Text(17348.0, 0, '2017-07'),
#   Text(17532.0, 0, '2018-01'),
#   Text(17713.0, 0, '2018-07'),
#   Text(17897.0, 0, '2019-01')])

# %%
plt.figure(figsize=(15,5))
data_monthly_avg = cleaned_df.groupby(['Order Month']).agg({'Price': 'mean'}).reset_index()
sns.barplot(x='Order Month', y='Price', data=data_monthly_avg).set(title="Monthly average sales");

# %%
cleaned_df['weekday'] = cleaned_df['Order Date'].dt.day_name()
#I look at the "Order date" column using pandas dt method to find out which day the sale was made.

# %%
plt.figure(figsize=(15,5))
colorscales = px.colors.named_colorscales()
data_weekday = cleaned_df.groupby(['weekday']).agg({'Price': 'mean'}).reset_index()
data_weekday.sort_values(by='Price', inplace=True)
sns.barplot(x='weekday', y='Price', data=data_weekday).set(title="Average sales by day of the week");

# %%
cleaned_df['quarter'] = df['Order Date'].dt.quarter
#It is method that obtain quarter value of chosen column.

# %%
plt.figure(figsize=(15,5))
data_quarter = cleaned_df.groupby('quarter').agg({'Price': 'mean'}).reset_index()
ax= sns.barplot(x='quarter', y='Price', data=data_quarter, color="olivedrab");
ax.bar_label(ax.containers[0]);

# %% [markdown]
# ## Year over growth year/ Total sales over the years

# %%
plt.figure(figsize=(15,5))
data_year=cleaned_df.groupby('Order Year').agg({'Price': 'sum'}).reset_index()
ax= sns.barplot(x='Order Year', y='Price', data=data_year, color="crimson").set(title="Total sales over the years");

# %%
plt.figure(figsize=(15,5))
data_year['yoy'] = round(data_year['Price'].pct_change()*100, 2)
sns.barplot(x='Order Year', y='yoy', data=data_year).set(title="Year over growth year")
#It is the method to get the percentage change of chosen column.
#"yoy"= year over growth year
# Out:
# [Text(0.5, 1.0, 'Year over growth year')]

# %% [markdown]
# ## Top customer of all times

# %%
plt.figure(figsize=(15,5))
data_top_customer = cleaned_df.groupby('Customer Name').agg({'Price': 'sum'}).reset_index()
data_top_customer.sort_values(by='Price',ascending=False, inplace=True)
sns.barplot(x='Customer Name', y='Price', data=data_top_customer.head(10), color="purple");
plt.xticks(rotation=45);

# %% [markdown]
# ## Top Cities

# %%
plt.figure(figsize=(15,5))
data_city = cleaned_df.groupby(['City']).agg({'Price': 'sum'}).reset_index()
data_city.sort_values(by='Price', ascending=False, inplace=True)

sns.barplot(x='City', y='Price', data=data_city.head(10), color="coral").set(title="Top 10 city");
plt.xticks(rotation=45);

# %% [markdown]
# ## Regional

# %%
data_region= cleaned_df.groupby('Region').agg(sales_sum=('Price','sum'), sales_mean=('Price', 'mean')).reset_index()
#Since I want to look at the average and the sum of our sales column at the same time, I used tuples like this.

# %%
plt.figure(figsize=(15,5))
data_region.sort_values(by='sales_sum', ascending=False, inplace=True)
sns.barplot(x='Region', y='sales_sum', data=data_region,palette ="hls").set(title="Regional sum");

# %% [markdown]
# ## Sales by category, subcategory and product

# %%
plt.figure(figsize=(15,5))
data_cat = cleaned_df.groupby(['Category']).agg({'Price':'sum'}).reset_index().sort_values(by='Price', ascending=False)
sns.barplot(x='Category', y='Price', data=data_cat).set(title="Sales by Category'");

# %% [markdown]
# ## Sub category

# %%
plt.figure(figsize=(15,5))
data_sub_cat = cleaned_df.groupby(['Sub-Category']).agg({'Price':'sum'}).reset_index().sort_values(by='Price', ascending=False)
sns.barplot(x='Sub-Category', y='Price', data=data_sub_cat, color="yellowgreen")
plt.xticks(rotation=45);

# %% [markdown]
# ## Sales by product

# %%
## Sales by product

plt.figure(figsize=(15,5))
data_product = cleaned_df.groupby(['Product Name']).agg({'Price':'sum'}).reset_index()
sns.barplot(x='Product Name', y='Price', data=data_product.head(5), color="aquamarine")
plt.xticks(rotation=45);

# %% [markdown]
# ## Top products in each

# %%
data_top_prod = cleaned_df.groupby(['Sub-Category', 'Product Name']).agg({'Price':'sum'}).reset_index()
data_top_prod.sort_values(by=['Price'], ascending=False, inplace=True)

# %%
data_top_prod['rank'] =data_top_prod.groupby(['Sub-Category'])['Price'].rank('dense',ascending=False)
#It is a method to get each sub-category number one product.

# %%
data_top_prod[data_top_prod['Sub-Category'] =='Machines']
# Out:
#      Sub-Category                                       Product Name  Price  \
# 1097     Machines  Cisco TelePresence System EX90 Videoconferenci...  22638
# 1105     Machines  HP Designjet T520 Inkjet Large Format Printer ...  18372
# 1117     Machines          Lexmark MX611dhe Monochrome Laser Printer  16826
# 1086     Machines   3D Systems Cube Printer, 2nd Generation, Magenta  14298
# 1090     Machines                        Bady BDG101FRU Card Printer   9276
# 1099     Machines          Cubify CubeX 3D Printer Triple Head Print   7999
# 1089     Machines                  Ativa V4110MDD Micro-Cut Shredder   7698
# 1143     Machines                  Zebra ZM400 Thermal Label Printer   6964
# 1098     Machines          Cubify CubeX 3D Printer Double Head Print   6598
# 1142     Machines  Zebra GX420t Direct Thermal/Thermal Transfer P...   5786
# 1126     Machines                              Okidata MB760 Printer   4476
# ...

# %%
data_top_prod[data_top_prod['Sub-Category'] =='Accessories']
# Out:
#     Sub-Category                                       Product Name  Price  \
# 114  Accessories  Plantronics Savi W720 Multi-Device Wireless He...   9362
# 112  Accessories  Plantronics CS510 - Over-the-Head monaural Wir...   7385
# 65   Accessories                      Logitech diNovo Edge Keyboard   5996
# 70   Accessories                 Logitech P710e Mobile Speakerphone   5557
# 117  Accessories  Razer Tiamat Over Ear 7.1 Surround Sound PC Ga...   5113
# ..           ...                                                ...    ...
# 122  Accessories                SanDisk Cruzer 4 GB USB Flash Drive     15
# 77   Accessories                          Maxell 4.7GB DVD-R 5/Pack     15
# 81   Accessories                                  Maxell CD-R Discs     14
# 96   Accessories  Memorex Mini Travel Drive 4 GB USB 2.0 Flash D...     13
# 74   Accessories                          Maxell 4.7GB DVD+R 5/Pack      7
#
#       rank
# 114    1.0
# 112    2.0
# 65     3.0
# 70     4.0
# ...

# %%
px.bar(data_top_prod[data_top_prod['rank'] == 1], x='Product Name', y='Price', color='Sub-Category', title='Top products in each sub category',width=1000, height=800,text_auto=True)

# %% [markdown]
# # 5. Communication Results

# %% [markdown]
# Conclusion
# According to data visualization;
#
# - Saturday and Thursday of the week are sales high on average.
# - Monthly average sales is highest at January.
# - Total sales is highest at 2018 but for year over growth year is at highest at 2017.
# - Top customer for all times is Sean Miller who is in segment of Home Office.
# - The highest sales by category is Technology.
# - New York has the highest sales then Los Angeles came. These are big and crowded city, for example it may be desirable to open another store in these city.
